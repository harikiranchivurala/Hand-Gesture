# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
from scipy.misc import imread, imresize
import datetime
import os

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.set_random_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('./Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('./Project_data/val.csv').readlines())
batch_size = 64 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = np.arange(0,30,3) #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,len(img_idx),50,50,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    image = imresize(image,(50,50))
                    
                    image = image - np.percentile(image,5)/ np.percentile(image,95) - np.percentile(image,5)
                    
                    batch_data[folder,idx,:,:,0] = image[:,:,0] #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = image[:,:,1]#normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = image[:,:,2] #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        rem_image = len(folder_list)%batch_size
        batch += 1
        if(rem_image!=0):
            batch_data = np.zeros((rem_image,len(img_idx),50,50,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((rem_image,5)) # batch_labels is the one hot representation of the output
            for folder in range(rem_image): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                   
                    image = imresize(image,(50,50))
                    image = image - np.percentile(image,5)/ np.percentile(image,95) - np.percentile(image,5)
                    batch_data[folder,idx,:,:,0] = image[:,:,0]
                    batch_data[folder,idx,:,:,1] = image[:,:,1]
                    batch_data[folder,idx,:,:,2] = image[:,:,2]
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = './Project_data/train'
val_path = './Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
num_classes = 5
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.layers.convolutional import Conv2D, MaxPooling2D, AveragePooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.regularizers import l2
from keras.layers import LSTM, GRU, Bidirectional, SimpleRNN, RNN

#write your model here
model = Sequential()
model.add(TimeDistributed(Conv2D(16, (2, 2), padding='same'),
                 input_shape=(10,50,50,3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(TimeDistributed(Conv2D(16, (2, 2))))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model.add(Dropout(0.2))

model.add(TimeDistributed(Conv2D(32, (2, 2), padding='same')))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(TimeDistributed(Conv2D(32, (2, 2), padding='same')))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model.add(Dropout(0.2))

model.add(TimeDistributed(Flatten()))
model.add(GRU(256, return_sequences=False, dropout=0.5))
model.add(Dense(64,kernel_regularizer=l2(0.01)))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = 'sgd' #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_15 (TimeDis (None, 10, 50, 50, 16)    208
# _________________________________________________________________
# activation_31 (Activation)   (None, 10, 50, 50, 16)    0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 10, 50, 50, 16)    64
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 10, 49, 49, 16)    1040
# _________________________________________________________________
# activation_32 (Activation)   (None, 10, 49, 49, 16)    0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 10, 49, 49, 16)    64
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, 10, 24, 24, 16)    0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 10, 24, 24, 16)    0
# _________________________________________________________________
# time_distributed_18 (TimeDis (None, 10, 24, 24, 32)    2080
# _________________________________________________________________
# activation_33 (Activation)   (None, 10, 24, 24, 32)    0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 10, 24, 24, 32)    128
# _________________________________________________________________
# time_distributed_19 (TimeDis (None, 10, 24, 24, 32)    4128
# _________________________________________________________________
# activation_34 (Activation)   (None, 10, 24, 24, 32)    0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 10, 24, 24, 32)    128
# _________________________________________________________________
# time_distributed_20 (TimeDis (None, 10, 12, 12, 32)    0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 10, 12, 12, 32)    0
# _________________________________________________________________
# time_distributed_21 (TimeDis (None, 10, 4608)          0
# _________________________________________________________________
# gru_3 (GRU)                  (None, 256)               3736320
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                16448
# _________________________________________________________________
# activation_35 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 5)                 325
# _________________________________________________________________
# activation_36 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 3,760,933
# Trainable params: 3,760,741
# Non-trainable params: 192
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.01)  # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ./Project_data/val ; batch size = 64
# Source path =  ./Project_data/train ; batch size = 64
# Epoch 1/50
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:43: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 11/11 [==============================] - 33s 3s/step - loss: 2.8822 - categorical_accuracy: 0.2377 - val_loss: 2.5967 - val_categorical_accuracy: 0.3000
#
# Epoch 00001: saving model to model_init_2020-12-2812_53_30.033004/model-00001-2.89257-0.24133-2.59673-0.30000.h5
# Epoch 2/50
# 11/11 [==============================] - 23s 2s/step - loss: 2.7230 - categorical_accuracy: 0.2481 - val_loss: 2.5527 - val_categorical_accuracy: 0.2700
#
# Epoch 00002: saving model to model_init_2020-12-2812_53_30.033004/model-00002-2.72394-0.24736-2.55272-0.27000.h5
# Epoch 3/50
# 11/11 [==============================] - 25s 2s/step - loss: 2.5947 - categorical_accuracy: 0.2995 - val_loss: 2.3784 - val_categorical_accuracy: 0.4400
#
# Epoch 00004: saving model to model_init_2020-12-2812_53_30.033004/model-00004-2.58836-0.30166-2.37842-0.44000.h5
# Epoch 5/50
# 11/11 [==============================] - 24s 2s/step - loss: 2.4891 - categorical_accuracy: 0.3598 - val_loss: 2.3752 - val_categorical_accuracy: 0.4700
#
# Epoch 00005: saving model to model_init_2020-12-2812_53_30.033004/model-00005-2.48885-0.36048-2.37524-0.47000.h5
# Epoch 6/50
# 11/11 [==============================] - 25s 2s/step - loss: 2.4646 - categorical_accuracy: 0.3669 - val_loss: 2.4272 - val_categorical_accuracy: 0.3800
#
# Epoch 00006: saving model to model_init_2020-12-2812_53_30.033004/model-00006-2.47010-0.36802-2.42716-0.38000.h5
# Epoch 7/50
# 11/11 [==============================] - 25s 2s/step - loss: 2.3080 - categorical_accuracy: 0.4615 - val_loss: 2.3057 - val_categorical_accuracy: 0.4600
#
# Epoch 00008: saving model to model_init_2020-12-2812_53_30.033004/model-00008-2.30429-0.46305-2.30568-0.46000.h5
# Epoch 9/50
# 11/11 [==============================] - 25s 2s/step - loss: 2.2715 - categorical_accuracy: 0.4267 - val_loss: 2.1178 - val_categorical_accuracy: 0.5800
#
# Epoch 00009: saving model to model_init_2020-12-2812_53_30.033004/model-00009-2.28505-0.42383-2.11782-0.58000.h5
# Epoch 10/50
# 11/11 [==============================] - 25s 2s/step - loss: 2.1836 - categorical_accuracy: 0.5360 - val_loss: 2.0660 - val_categorical_accuracy: 0.6100
#
# Epoch 00010: saving model to model_init_2020-12-2812_53_30.033004/model-00010-2.19162-0.52941-2.06600-0.61000.h5
# Epoch 11/50
# 11/11 [==============================] - 25s 2s/step - loss: 2.1170 - categorical_accuracy: 0.5397 - val_loss: 2.0456 - val_categorical_accuracy: 0.5800
#
# Epoch 00011: saving model to model_init_2020-12-2812_53_30.033004/model-00011-2.12612-0.53092-2.04565-0.58000.h5
# Epoch 12/50
# 11/11 [==============================] - 25s 2s/step - loss: 2.1116 - categorical_accuracy: 0.5570 - val_loss: 2.0371 - val_categorical_accuracy: 0.6500
#
# Epoch 00012: saving model to model_init_2020-12-2812_53_30.033004/model-00012-2.11381-0.55656-2.03711-0.65000.h5
# Epoch 13/50
# 11/11 [==============================] - 25s 2s/step - loss: 2.0702 - categorical_accuracy: 0.5663 - val_loss: 2.0026 - val_categorical_accuracy: 0.6500
#
# Epoch 00013: saving model to model_init_2020-12-2812_53_30.033004/model-00013-2.08222-0.55656-2.00262-0.65000.h5
# Epoch 14/50
# 11/11 [==============================] - 25s 2s/step - loss: 2.0064 - categorical_accuracy: 0.5740 - val_loss: 2.1485 - val_categorical_accuracy: 0.5800
#
# Epoch 00014: saving model to model_init_2020-12-2812_53_30.033004/model-00014-2.01888-0.56712-2.14846-0.58000.h5
# Epoch 15/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.9735 - categorical_accuracy: 0.5979 - val_loss: 2.0784 - val_categorical_accuracy: 0.5800
#
# Epoch 00015: saving model to model_init_2020-12-2812_53_30.033004/model-00015-1.97224-0.59729-2.07840-0.58000.h5
# Epoch 16/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.9361 - categorical_accuracy: 0.6170 - val_loss: 1.9795 - val_categorical_accuracy: 0.6000
#
# Epoch 00016: saving model to model_init_2020-12-2812_53_30.033004/model-00016-1.93181-0.61991-1.97953-0.60000.h5
# Epoch 17/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.9255 - categorical_accuracy: 0.5922 - val_loss: 2.0934 - val_categorical_accuracy: 0.6400
#
# Epoch 00017: saving model to model_init_2020-12-2812_53_30.033004/model-00017-1.92766-0.59125-2.09338-0.64000.h5
# Epoch 18/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.8831 - categorical_accuracy: 0.6225 - val_loss: 2.4207 - val_categorical_accuracy: 0.5300
#
# Epoch 00018: saving model to model_init_2020-12-2812_53_30.033004/model-00018-1.88475-0.61840-2.42074-0.53000.h5
# Epoch 19/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.8497 - categorical_accuracy: 0.6175 - val_loss: 1.8843 - val_categorical_accuracy: 0.6900
#
# Epoch 00019: saving model to model_init_2020-12-2812_53_30.033004/model-00019-1.84516-0.62293-1.88427-0.69000.h5
# Epoch 20/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.7974 - categorical_accuracy: 0.6443 - val_loss: 1.8698 - val_categorical_accuracy: 0.7100
#
# Epoch 00020: saving model to model_init_2020-12-2812_53_30.033004/model-00020-1.81137-0.63650-1.86981-0.71000.h5
# Epoch 21/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.7903 - categorical_accuracy: 0.6698 - val_loss: 1.9565 - val_categorical_accuracy: 0.6000
#
# Epoch 00021: saving model to model_init_2020-12-2812_53_30.033004/model-00021-1.77874-0.67572-1.95647-0.60000.h5
# Epoch 22/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.7588 - categorical_accuracy: 0.6780 - val_loss: 1.8970 - val_categorical_accuracy: 0.6900
#
# Epoch 00022: saving model to model_init_2020-12-2812_53_30.033004/model-00022-1.76776-0.66968-1.89696-0.69000.h5
# Epoch 23/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.7394 - categorical_accuracy: 0.6825 - val_loss: 1.9495 - val_categorical_accuracy: 0.6500
#
# Epoch 00023: saving model to model_init_2020-12-2812_53_30.033004/model-00023-1.74042-0.68175-1.94948-0.65000.h5
# Epoch 24/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.7364 - categorical_accuracy: 0.7011 - val_loss: 2.2104 - val_categorical_accuracy: 0.6300
#
# Epoch 00024: saving model to model_init_2020-12-2812_53_30.033004/model-00024-1.73429-0.70136-2.21037-0.63000.h5
# Epoch 25/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.7163 - categorical_accuracy: 0.6957 - val_loss: 2.6605 - val_categorical_accuracy: 0.5500
#
# Epoch 00025: saving model to model_init_2020-12-2812_53_30.033004/model-00025-1.71778-0.69080-2.66047-0.55000.h5
# Epoch 26/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.6291 - categorical_accuracy: 0.7307 - val_loss: 2.1033 - val_categorical_accuracy: 0.6200
#
# Epoch 00026: saving model to model_init_2020-12-2812_53_30.033004/model-00026-1.62900-0.73756-2.10333-0.62000.h5
# Epoch 27/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.6433 - categorical_accuracy: 0.7059 - val_loss: 2.5378 - val_categorical_accuracy: 0.5400
#
# Epoch 00027: saving model to model_init_2020-12-2812_53_30.033004/model-00027-1.63720-0.70890-2.53777-0.54000.h5
# Epoch 28/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.6121 - categorical_accuracy: 0.7257 - val_loss: 2.0425 - val_categorical_accuracy: 0.6400
#
# Epoch 00028: saving model to model_init_2020-12-2812_53_30.033004/model-00028-1.61632-0.72247-2.04251-0.64000.h5
# Epoch 29/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.6057 - categorical_accuracy: 0.7532 - val_loss: 2.0257 - val_categorical_accuracy: 0.6600
#
# Epoch 00029: saving model to model_init_2020-12-2812_53_30.033004/model-00029-1.61440-0.74661-2.02568-0.66000.h5
# Epoch 30/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.6074 - categorical_accuracy: 0.7257 - val_loss: 1.9784 - val_categorical_accuracy: 0.6300
#
# Epoch 00030: saving model to model_init_2020-12-2812_53_30.033004/model-00030-1.61847-0.72247-1.97840-0.63000.h5
# Epoch 31/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.5720 - categorical_accuracy: 0.7296 - val_loss: 2.0470 - val_categorical_accuracy: 0.6700
#
# Epoch 00031: saving model to model_init_2020-12-2812_53_30.033004/model-00031-1.57039-0.73152-2.04695-0.67000.h5
# Epoch 32/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.6147 - categorical_accuracy: 0.7187 - val_loss: 2.2599 - val_categorical_accuracy: 0.5700
#
# Epoch 00032: saving model to model_init_2020-12-2812_53_30.033004/model-00032-1.60009-0.72247-2.25987-0.57000.h5
# Epoch 33/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.5682 - categorical_accuracy: 0.7425 - val_loss: 1.7634 - val_categorical_accuracy: 0.7300
#
# Epoch 00033: saving model to model_init_2020-12-2812_53_30.033004/model-00033-1.56344-0.74510-1.76340-0.73000.h5
# Epoch 34/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.4982 - categorical_accuracy: 0.7732 - val_loss: 1.7108 - val_categorical_accuracy: 0.7500
#
# Epoch 00034: saving model to model_init_2020-12-2812_53_30.033004/model-00034-1.50056-0.76772-1.71081-0.75000.h5
# Epoch 35/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.4857 - categorical_accuracy: 0.7894 - val_loss: 1.9996 - val_categorical_accuracy: 0.6900
#
# Epoch 00035: saving model to model_init_2020-12-2812_53_30.033004/model-00035-1.48875-0.78733-1.99960-0.69000.h5
# Epoch 36/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.5059 - categorical_accuracy: 0.7628 - val_loss: 1.7579 - val_categorical_accuracy: 0.7500
#
# Epoch 00036: saving model to model_init_2020-12-2812_53_30.033004/model-00036-1.50898-0.76169-1.75792-0.75000.h5
# Epoch 37/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.4440 - categorical_accuracy: 0.7894 - val_loss: 2.0754 - val_categorical_accuracy: 0.6400
#
# Epoch 00037: saving model to model_init_2020-12-2812_53_30.033004/model-00037-1.43938-0.78733-2.07541-0.64000.h5
# Epoch 38/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.4595 - categorical_accuracy: 0.7735 - val_loss: 1.7728 - val_categorical_accuracy: 0.7100
#
# Epoch 00038: saving model to model_init_2020-12-2812_53_30.033004/model-00038-1.45106-0.78281-1.77282-0.71000.h5
# Epoch 39/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.3998 - categorical_accuracy: 0.8146 - val_loss: 1.8283 - val_categorical_accuracy: 0.7100
#
# Epoch 00039: saving model to model_init_2020-12-2812_53_30.033004/model-00039-1.40729-0.81146-1.82833-0.71000.h5
# Epoch 40/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.4308 - categorical_accuracy: 0.7739 - val_loss: 1.7953 - val_categorical_accuracy: 0.7400
#
# Epoch 00040: saving model to model_init_2020-12-2812_53_30.033004/model-00040-1.42828-0.77828-1.79528-0.74000.h5
# Epoch 41/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.4028 - categorical_accuracy: 0.8126 - val_loss: 1.9208 - val_categorical_accuracy: 0.6600
#
# Epoch 00041: saving model to model_init_2020-12-2812_53_30.033004/model-00041-1.41496-0.80694-1.92082-0.66000.h5
# Epoch 42/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.4204 - categorical_accuracy: 0.7971 - val_loss: 2.3385 - val_categorical_accuracy: 0.5600
#
# Epoch 00042: saving model to model_init_2020-12-2812_53_30.033004/model-00042-1.41936-0.79789-2.33847-0.56000.h5
# Epoch 43/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.3857 - categorical_accuracy: 0.8099 - val_loss: 1.7251 - val_categorical_accuracy: 0.7800
#
# Epoch 00043: saving model to model_init_2020-12-2812_53_30.033004/model-00043-1.38215-0.81146-1.72510-0.78000.h5
# Epoch 44/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.3424 - categorical_accuracy: 0.8247 - val_loss: 1.7253 - val_categorical_accuracy: 0.7400
#
# Epoch 00044: saving model to model_init_2020-12-2812_53_30.033004/model-00044-1.33500-0.82956-1.72528-0.74000.h5
# Epoch 45/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.3431 - categorical_accuracy: 0.8297 - val_loss: 1.8742 - val_categorical_accuracy: 0.7100
#
# Epoch 00045: saving model to model_init_2020-12-2812_53_30.033004/model-00045-1.35237-0.82504-1.87419-0.71000.h5
# Epoch 46/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.3672 - categorical_accuracy: 0.8080 - val_loss: 1.8313 - val_categorical_accuracy: 0.7000
#
# Epoch 00046: saving model to model_init_2020-12-2812_53_30.033004/model-00046-1.36241-0.80694-1.83127-0.70000.h5
# Epoch 47/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.2926 - categorical_accuracy: 0.8313 - val_loss: 1.7555 - val_categorical_accuracy: 0.7000
#
# Epoch 00047: saving model to model_init_2020-12-2812_53_30.033004/model-00047-1.29078-0.83409-1.75548-0.70000.h5
# Epoch 48/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.3481 - categorical_accuracy: 0.8165 - val_loss: 1.6006 - val_categorical_accuracy: 0.7600
#
# Epoch 00048: saving model to model_init_2020-12-2812_53_30.033004/model-00048-1.33889-0.81599-1.60059-0.76000.h5
# Epoch 49/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.3045 - categorical_accuracy: 0.8388 - val_loss: 1.6995 - val_categorical_accuracy: 0.7600
#
# Epoch 00049: saving model to model_init_2020-12-2812_53_30.033004/model-00049-1.30396-0.83710-1.69954-0.76000.h5
# Epoch 50/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.2518 - categorical_accuracy: 0.8706 - val_loss: 1.6395 - val_categorical_accuracy: 0.7600
#
# Epoch 00050: saving model to model_init_2020-12-2812_53_30.033004/model-00050-1.25097-0.86576-1.63946-0.76000.h5

# %% [markdown]
# ####  Conv3D Model

# %%
Input_shape = (10, 50, 50, 3)
model = Sequential()
model.add(Conv3D(32, (3,3,3), padding='same',
                 input_shape=Input_shape))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv3D(32, (3, 3,3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2,2)))
model.add(Dropout(0.5))

model.add(Conv3D(64, (3, 3,3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv3D(64, (3, 3,3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2,2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
optimiser = 'sgd' #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_9 (Conv3D)            (None, 10, 50, 50, 32)    2624
# _________________________________________________________________
# activation_19 (Activation)   (None, 10, 50, 50, 32)    0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 10, 50, 50, 32)    128
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 8, 48, 48, 32)     27680
# _________________________________________________________________
# activation_20 (Activation)   (None, 8, 48, 48, 32)     0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 8, 48, 48, 32)     128
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 4, 24, 24, 32)     0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 4, 24, 24, 32)     0
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 4, 24, 24, 64)     55360
# _________________________________________________________________
# activation_21 (Activation)   (None, 4, 24, 24, 64)     0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 4, 24, 24, 64)     256
# _________________________________________________________________
# conv3d_12 (Conv3D)           (None, 2, 22, 22, 64)     110656
# _________________________________________________________________
# activation_22 (Activation)   (None, 2, 22, 22, 64)     0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 2, 22, 22, 64)     256
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 1, 11, 11, 64)     0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1, 11, 11, 64)     0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 7744)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               1982720
# _________________________________________________________________
# activation_23 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 5)                 1285
# _________________________________________________________________
# activation_24 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 2,181,093
# Trainable params: 2,180,709
# Non-trainable params: 384
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_conv_3D' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.01)  # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ./Project_data/val ; batch size = 64
# Source path =  ./Project_data/train ; batch size = 64
# Epoch 1/50
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:43: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 11/11 [==============================] - 33s 3s/step - loss: 5.4411 - categorical_accuracy: 0.2615 - val_loss: 4.3419 - val_categorical_accuracy: 0.2700
#
# Epoch 00001: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00001-5.52579-0.26395-4.34193-0.27000.h5
# Epoch 2/50
# 11/11 [==============================] - 23s 2s/step - loss: 2.0412 - categorical_accuracy: 0.3973 - val_loss: 1.1503 - val_categorical_accuracy: 0.4800
#
# Epoch 00002: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00002-2.05921-0.39517-1.15033-0.48000.h5
# Epoch 3/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.4840 - categorical_accuracy: 0.4819 - val_loss: 1.1789 - val_categorical_accuracy: 0.5400
#
# Epoch 00003: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00003-1.49294-0.47964-1.17891-0.54000.h5
# Epoch 4/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.3924 - categorical_accuracy: 0.4631 - val_loss: 0.9996 - val_categorical_accuracy: 0.5400
#
# Epoch 00004: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00004-1.37199-0.47210-0.99962-0.54000.h5
# Epoch 5/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.2436 - categorical_accuracy: 0.5087 - val_loss: 1.0396 - val_categorical_accuracy: 0.6000
#
# Epoch 00005: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00005-1.24269-0.51282-1.03959-0.60000.h5
# Epoch 6/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.1125 - categorical_accuracy: 0.5563 - val_loss: 1.1787 - val_categorical_accuracy: 0.5800
#
# Epoch 00006: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00006-1.11378-0.56561-1.17866-0.58000.h5
# Epoch 7/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.0662 - categorical_accuracy: 0.5720 - val_loss: 1.0558 - val_categorical_accuracy: 0.5500
#
# Epoch 00007: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00007-1.04672-0.58220-1.05577-0.55000.h5
# Epoch 8/50
# 11/11 [==============================] - 24s 2s/step - loss: 1.0661 - categorical_accuracy: 0.5870 - val_loss: 0.9916 - val_categorical_accuracy: 0.5800
#
# Epoch 00008: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00008-1.05660-0.58824-0.99156-0.58000.h5
# Epoch 9/50
# 11/11 [==============================] - 25s 2s/step - loss: 1.0157 - categorical_accuracy: 0.5645 - val_loss: 0.9815 - val_categorical_accuracy: 0.5300
#
# Epoch 00009: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00009-1.02878-0.55958-0.98149-0.53000.h5
# Epoch 10/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.9514 - categorical_accuracy: 0.6145 - val_loss: 1.0178 - val_categorical_accuracy: 0.5600
#
# Epoch 00010: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00010-0.94246-0.61237-1.01783-0.56000.h5
# Epoch 11/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.9400 - categorical_accuracy: 0.6099 - val_loss: 0.9869 - val_categorical_accuracy: 0.5900
#
# Epoch 00011: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00011-0.93693-0.61237-0.98691-0.59000.h5
# Epoch 12/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.9137 - categorical_accuracy: 0.6084 - val_loss: 0.9961 - val_categorical_accuracy: 0.6200
#
# Epoch 00012: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00012-0.89220-0.61086-0.99613-0.62000.h5
# Epoch 13/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.8847 - categorical_accuracy: 0.6350 - val_loss: 0.9261 - val_categorical_accuracy: 0.5900
#
# Epoch 00013: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00013-0.88300-0.63650-0.92610-0.59000.h5
# Epoch 14/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.8448 - categorical_accuracy: 0.6580 - val_loss: 0.9790 - val_categorical_accuracy: 0.6000
#
# Epoch 00014: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00014-0.83185-0.66817-0.97899-0.60000.h5
# Epoch 15/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.7904 - categorical_accuracy: 0.6693 - val_loss: 0.9374 - val_categorical_accuracy: 0.5900
#
# Epoch 00015: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00015-0.79159-0.67270-0.93739-0.59000.h5
# Epoch 16/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.7484 - categorical_accuracy: 0.6944 - val_loss: 1.0453 - val_categorical_accuracy: 0.6000
#
# Epoch 00016: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00016-0.75374-0.69683-1.04529-0.60000.h5
# Epoch 17/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.6942 - categorical_accuracy: 0.7393 - val_loss: 0.9366 - val_categorical_accuracy: 0.6400
#
# Epoch 00017: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00017-0.71037-0.72700-0.93658-0.64000.h5
# Epoch 18/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.6564 - categorical_accuracy: 0.7419 - val_loss: 1.0685 - val_categorical_accuracy: 0.6300
#
# Epoch 00018: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00018-0.65023-0.74208-1.06845-0.63000.h5
# Epoch 19/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.6956 - categorical_accuracy: 0.7125 - val_loss: 0.9543 - val_categorical_accuracy: 0.6100
#
# Epoch 00019: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00019-0.70145-0.71342-0.95431-0.61000.h5
# Epoch 20/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.6717 - categorical_accuracy: 0.7375 - val_loss: 1.0058 - val_categorical_accuracy: 0.6300
#
# Epoch 00020: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00020-0.68137-0.73002-1.00575-0.63000.h5
# Epoch 21/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.6032 - categorical_accuracy: 0.7708 - val_loss: 0.9494 - val_categorical_accuracy: 0.6600
#
# Epoch 00021: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00021-0.61512-0.76772-0.94944-0.66000.h5
# Epoch 22/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.6413 - categorical_accuracy: 0.7494 - val_loss: 0.9106 - val_categorical_accuracy: 0.6800
#
# Epoch 00022: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00022-0.63887-0.74510-0.91060-0.68000.h5
# Epoch 23/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.6142 - categorical_accuracy: 0.7337 - val_loss: 0.9550 - val_categorical_accuracy: 0.6400
#
# Epoch 00023: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00023-0.62247-0.72851-0.95498-0.64000.h5
# Epoch 24/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.6183 - categorical_accuracy: 0.7660 - val_loss: 0.9056 - val_categorical_accuracy: 0.6300
#
# Epoch 00024: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00024-0.62781-0.76018-0.90562-0.63000.h5
# Epoch 25/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.6288 - categorical_accuracy: 0.7416 - val_loss: 0.8636 - val_categorical_accuracy: 0.6600
#
# Epoch 00025: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00025-0.61568-0.74661-0.86359-0.66000.h5
# Epoch 26/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.5410 - categorical_accuracy: 0.7962 - val_loss: 1.0938 - val_categorical_accuracy: 0.6800
#
# Epoch 00026: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00026-0.53381-0.79940-1.09381-0.68000.h5
# Epoch 27/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.5374 - categorical_accuracy: 0.7794 - val_loss: 1.0787 - val_categorical_accuracy: 0.6400
#
# Epoch 00027: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00027-0.53994-0.77677-1.07865-0.64000.h5
# Epoch 28/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.4907 - categorical_accuracy: 0.8199 - val_loss: 1.0476 - val_categorical_accuracy: 0.6200
#
# Epoch 00028: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00028-0.47994-0.82202-1.04762-0.62000.h5
# Epoch 29/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.5193 - categorical_accuracy: 0.8028 - val_loss: 1.1806 - val_categorical_accuracy: 0.6400
#
# Epoch 00029: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00029-0.51631-0.80392-1.18064-0.64000.h5
# Epoch 30/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.4575 - categorical_accuracy: 0.8213 - val_loss: 1.1444 - val_categorical_accuracy: 0.6600
#
# Epoch 00030: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00030-0.46144-0.82353-1.14441-0.66000.h5
# Epoch 31/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.5351 - categorical_accuracy: 0.8028 - val_loss: 1.0479 - val_categorical_accuracy: 0.6500
#
# Epoch 00031: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00031-0.52967-0.80392-1.04795-0.65000.h5
# Epoch 32/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.4447 - categorical_accuracy: 0.8212 - val_loss: 0.9348 - val_categorical_accuracy: 0.6500
#
# Epoch 00032: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00032-0.45277-0.81599-0.93477-0.65000.h5
# Epoch 33/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.4789 - categorical_accuracy: 0.8060 - val_loss: 0.9464 - val_categorical_accuracy: 0.6600
#
# Epoch 00033: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00033-0.48747-0.80241-0.94635-0.66000.h5
# Epoch 34/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.4229 - categorical_accuracy: 0.8394 - val_loss: 0.9138 - val_categorical_accuracy: 0.6600
#
# Epoch 00034: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00034-0.42456-0.84012-0.91379-0.66000.h5
# Epoch 35/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.4168 - categorical_accuracy: 0.8156 - val_loss: 0.9500 - val_categorical_accuracy: 0.6300
#
# Epoch 00035: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00035-0.41980-0.81750-0.95000-0.63000.h5
# Epoch 36/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.3852 - categorical_accuracy: 0.8583 - val_loss: 0.9307 - val_categorical_accuracy: 0.6700
#
# Epoch 00036: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00036-0.39149-0.85520-0.93069-0.67000.h5
# Epoch 37/50
# 11/11 [==============================] - 25s 2s/step - loss: 0.3882 - categorical_accuracy: 0.8397 - val_loss: 0.9294 - val_categorical_accuracy: 0.6800
#
# Epoch 00037: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00037-0.39259-0.83560-0.92936-0.68000.h5
# Epoch 38/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.3895 - categorical_accuracy: 0.8422 - val_loss: 1.0728 - val_categorical_accuracy: 0.6800
#
# Epoch 00038: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00038-0.38986-0.84314-1.07279-0.68000.h5
# Epoch 39/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.3728 - categorical_accuracy: 0.8365 - val_loss: 1.1514 - val_categorical_accuracy: 0.6400
#
# Epoch 00039: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00039-0.37255-0.83710-1.15139-0.64000.h5
# Epoch 40/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.3848 - categorical_accuracy: 0.8540 - val_loss: 0.9355 - val_categorical_accuracy: 0.7200
#
# Epoch 00040: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00040-0.39094-0.85068-0.93548-0.72000.h5
# Epoch 41/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.3298 - categorical_accuracy: 0.8760 - val_loss: 1.0324 - val_categorical_accuracy: 0.6900
#
# Epoch 00041: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00041-0.33244-0.87632-1.03236-0.69000.h5
# Epoch 42/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.3645 - categorical_accuracy: 0.8551 - val_loss: 1.0025 - val_categorical_accuracy: 0.6900
#
# Epoch 00042: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00042-0.36730-0.85671-1.00246-0.69000.h5
# Epoch 43/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.3076 - categorical_accuracy: 0.8760 - val_loss: 0.9704 - val_categorical_accuracy: 0.6800
#
# Epoch 00043: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00043-0.31118-0.87632-0.97041-0.68000.h5
# Epoch 44/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.3553 - categorical_accuracy: 0.8651 - val_loss: 1.0759 - val_categorical_accuracy: 0.6600
#
# Epoch 00044: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00044-0.35104-0.86727-1.07587-0.66000.h5
# Epoch 45/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.2768 - categorical_accuracy: 0.9034 - val_loss: 0.9370 - val_categorical_accuracy: 0.6700
#
# Epoch 00045: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00045-0.28184-0.90045-0.93703-0.67000.h5
# Epoch 46/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.2947 - categorical_accuracy: 0.8854 - val_loss: 0.9403 - val_categorical_accuracy: 0.6500
#
# Epoch 00046: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00046-0.30122-0.88386-0.94032-0.65000.h5
# Epoch 47/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.3064 - categorical_accuracy: 0.8751 - val_loss: 1.0021 - val_categorical_accuracy: 0.6700
#
# Epoch 00047: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00047-0.29630-0.87783-1.00212-0.67000.h5
# Epoch 48/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.3130 - categorical_accuracy: 0.8845 - val_loss: 0.9265 - val_categorical_accuracy: 0.6900
#
# Epoch 00048: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00048-0.31134-0.88537-0.92645-0.69000.h5
# Epoch 49/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.2410 - categorical_accuracy: 0.9015 - val_loss: 1.0240 - val_categorical_accuracy: 0.6600
#
# Epoch 00049: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00049-0.25164-0.89593-1.02396-0.66000.h5
# Epoch 50/50
# 11/11 [==============================] - 24s 2s/step - loss: 0.3204 - categorical_accuracy: 0.8822 - val_loss: 1.0602 - val_categorical_accuracy: 0.6800
#
# Epoch 00050: saving model to model_conv_3D_2020-12-2811_21_22.630930/model-00050-0.32152-0.88537-1.06018-0.68000.h5
